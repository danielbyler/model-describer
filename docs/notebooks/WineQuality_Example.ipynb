# %% [markdown]
# ## WhiteBox Error and Sensitivity Analysis on Wine Quality Data
#
# Goals of tutorial include:
# * [Importing wine quality dataset](#wine_quality)
# * [Handling categorical features](#categorical)
# * [Build model](#model)
# * [Deploying WhiteBoxError graphics](#wbox_error)
# * [Deploying WhiteBoxSensitivity graphics](#wbox_sensitivity)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

from whitebox.utils import utils as wb_utils
from whitebox.eval import WhiteBoxError, WhiteBoxSensitivity

# %% [markdown]
# ### Import wine quality dataset <a id=wine_quality><a>
# Perform basic exploratory data analysis to better understand what types of columns are available

# %%
df = pd.read_csv('./datasets/winequality.csv')

# %%
df.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    quality Type AlcoholContent
# 0        5  Red            Low
# 1        5  Red            Low
# 2        5  Red            Low
# 3        6  Red            Low
# 4        5  Red            Low

# %%
df.dtypes # it looks like most of our columns are numeric, with the exception of Type and AlcoholContent
# Out:
# fixed.acidity           float64
# volatile.acidity        float64
# citric.acid             float64
# residual.sugar          float64
# chlorides               float64
# free.sulfur.dioxide     float64
# total.sulfur.dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# quality                   int64
# Type                     object
# AlcoholContent           object
# dtype: object

# %%
df.groupby('AlcoholContent')['fixed.acidity'].count() # most of our data resides in low/medium alcohol content
# Out:
# AlcoholContent
# High       852
# Low       2832
# Medium    2813
# Name: fixed.acidity, dtype: int64

# %%
df.groupby('Type')['fixed.acidity'].count() # and most of our data is white wine
# Out:
# Type
# Red      1599
# White    4898
# Name: fixed.acidity, dtype: int64

# %% [markdown]
# ### Handling categorical data <a id=categorical><a>
#
# We can rely on pandas to convert our string/category columns into dummy variables to be used in our models

# %%
# dependent variables
ydepend = 'quality'

# create model data frame which will have categories converted to dummies
model_df = pd.get_dummies(df.loc[:, df.columns!=ydepend])

# %% [markdown]
# ### Build model <a id=model><a>

# %%
# build the model
modelobj = RandomForestRegressor()

modelobj.fit(model_df, df.loc[:, ydepend])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ### Create WhiteBoxError <a id=wbox_error><a>

# %%
# specify keepfeaturelist as a subset of columns we want to focus on

keepfeaturelist = ['fixed.acidity', 
                  'quality', 
                  'AlcoholContent', 
                  'sulphates', 
                  'volatile.acidity', 
                  'residual.sugar', 
                  'free.sulfur.dioxide', 
                  'ALL DATA']


# hack it for one groupby variable so we can also see how the model is doing across the entire space
df['ALL DATA'] = 'ALL DATA'

# specify the groupby variables
groupbyvars = ['AlcoholContent', 'ALL DATA']

# instantiate wbox error
WB = WhiteBoxError(modelobj=modelobj,
                   model_df=model_df,
                   ydepend=ydepend,
                   cat_df=df, 
                   groupbyvars=groupbyvars,
                   keepfeaturelist=keepfeaturelist,
                   autoformat_types=True,
                   verbose=None,
                   round_num=4)

# %%
# run wbox error
WB.run(output_type='html', output_path='winequality_example.html')
# Out:
# Percent Complete:  0%
# C:\Users\jlewris\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1018: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Percent Complete: 86%

# %%
WB._save('winequality_example.html')

# %%
WB.outputs
# Out:
# [{'Data': [{'ALL DATA': 'ALL DATA',
#     'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2},
#    {'ALL DATA': 'ALL DATA',
#     'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0},
#    {'ALL DATA': 'ALL DATA',
#     'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.6}],
#   'Type': 'Categorical'},
#  {'Data': [{'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 0.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 1.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.2},
#    {'errNeg': -0.1,
#     'errPos': 0.3,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 1.25},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.5},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.6},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.7},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.9},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 1.95},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 2.0},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 2.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 2.2},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 2.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.4},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 2.5},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 2.6},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.7},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 2.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 3.4},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.8},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 4.1},
#    {'errNeg': -0.05,
#     'errPos': 0.05,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 4.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 4.5},
#    {'errNeg': -0.15,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 4.65},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 4.8},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.2},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 5.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 6.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 6.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 6.5},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 6.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 7.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 7.1},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 7.4},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.7,
#     'residual.sugar': 7.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 7.8},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 7.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 8.1},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 8.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 8.55},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 8.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.95,
#     'residual.sugar': 9.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 9.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 9.9},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 10.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 10.6},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 10.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.7,
#     'residual.sugar': 11.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 11.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 12.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.6,
#     'residual.sugar': 12.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 12.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 13.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.6,
#     'residual.sugar': 13.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 13.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 14.2},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 14.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 15.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 15.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 16.4},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 17.35},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 18.2},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.4,
#     'residual.sugar': 65.8},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 1.0},
#    {'errNeg': -0.2,
#     'errPos': 0.15,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.6,
#     'residual.sugar': 1.1},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.35,
#     'residual.sugar': 1.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 1.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 1.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.45,
#     'residual.sugar': 1.5},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 1.6},
#    {'errNeg': -0.1,
#     'errPos': 'null',
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 4.9,
#     'residual.sugar': 1.65},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 1.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 1.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 1.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.0},
#    {'errNeg': -0.05,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.2},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.3},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.4},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 2.5},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.8},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 2.9},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 3.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 3.3},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 3.6},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 4.1},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.05,
#     'residual.sugar': 4.5},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.15,
#     'residual.sugar': 4.8},
#    {'errNeg': -0.2,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.45,
#     'residual.sugar': 5.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 5.2},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.45,
#     'residual.sugar': 5.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.7,
#     'residual.sugar': 6.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 6.3},
#    {'errNeg': -0.2,
#     'errPos': 0.2,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 6.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 6.7},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 7.0},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 7.1},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.05,
#     'residual.sugar': 7.2},
#    {'errNeg': -0.05,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.4,
#     'residual.sugar': 7.5},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.25,
#     'residual.sugar': 7.6},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.15,
#     'residual.sugar': 7.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 7.8},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 8.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 8.1},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 8.2},
#    {'errNeg': -0.05,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 8.5},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.15,
#     'residual.sugar': 8.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.05,
#     'residual.sugar': 8.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 9.3},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 9.7},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 10.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.4,
#     'residual.sugar': 10.3},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 10.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 10.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 11.0},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 11.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.4,
#     'residual.sugar': 11.5},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.45,
#     'residual.sugar': 11.8},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.75,
#     'residual.sugar': 11.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.15,
#     'residual.sugar': 12.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.65,
#     'residual.sugar': 12.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 12.5},
#    {'errNeg': -0.15,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.75,
#     'residual.sugar': 12.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 12.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.7,
#     'residual.sugar': 13.1},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.5,
#     'residual.sugar': 13.2},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 13.5},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 13.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.95,
#     'residual.sugar': 13.9},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 14.2},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.65,
#     'residual.sugar': 14.35},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 14.5},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 14.75},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.4,
#     'residual.sugar': 15.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.15,
#     'residual.sugar': 15.4},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 15.55},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.3,
#     'residual.sugar': 16.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.0,
#     'residual.sugar': 16.4},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 16.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 17.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.85,
#     'residual.sugar': 17.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.0,
#     'residual.sugar': 18.15},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 19.25},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 31.6},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.55,
#     'residual.sugar': 0.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.95,
#     'residual.sugar': 1.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.1},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.2},
#    {'errNeg': -0.1,
#     'errPos': 0.3,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 1.25},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.5},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.6},
#    {'errNeg': -0.2,
#     'errPos': 0.4,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.1,
#     'residual.sugar': 1.65},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.7},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 1.8},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 1.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.1},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 2.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.5},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.6},
#    {'errNeg': -0.2,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 2.7},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 2.8},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 2.9},
#    {'errNeg': -0.1,
#     'errPos': 0.15,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 3.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 3.6},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 3.8},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 4.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.2,
#     'residual.sugar': 4.2},
#    {'errNeg': -0.1,
#     'errPos': 0.15,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 4.5},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 4.6},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 4.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.0},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 5.4},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.4,
#     'residual.sugar': 5.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 5.8},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 6.0},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 6.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 6.4},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 6.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 6.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 6.9},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.2,
#     'residual.sugar': 7.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'residual.sugar': 7.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 7.4},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 7.8},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 8.1},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 8.3},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 8.7},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 8.9},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 9.2},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.95,
#     'residual.sugar': 9.65},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 9.9},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 10.4},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 10.7},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 11.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 11.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.9,
#     'residual.sugar': 12.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 13.1},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 14.2},
#    {'errNeg': -0.2,
#     'errPos': 0.25,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.75,
#     'residual.sugar': 15.8},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 5.8,
#     'residual.sugar': 65.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'residual.sugar': 0.9},
#    {'errNeg': -0.25,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 1.0},
#    {'errNeg': -0.2,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 1.1},
#    {'errNeg': -0.05,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 1.2},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.4,
#     'residual.sugar': 1.3},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.45,
#     'residual.sugar': 1.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 1.5},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.55,
#     'residual.sugar': 1.6},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.2,
#     'residual.sugar': 1.7},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.7,
#     'residual.sugar': 1.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.4,
#     'residual.sugar': 1.9},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 1.95},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 2.0},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.5,
#     'residual.sugar': 2.1},
#    {'errNeg': -0.1,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'residual.sugar': 2.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.2,
#     'residual.sugar': 2.3},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 2.4},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 2.5},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.6,
#     'residual.sugar': 2.6},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 2.7},
#    {'errNeg': -0.15,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.45,
#     'residual.sugar': 2.8},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.2,
#     'residual.sugar': 2.9},
#    {'errNeg': -0.2,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 3.0},
#    {'errNeg': -0.05,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 3.1},
#    {'errNeg': -0.25,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.5,
#     'residual.sugar': 3.2},
#    {'errNeg': -0.2,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'residual.sugar': 3.3},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.45,
#     'residual.sugar': 3.5},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 3.6},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'residual.sugar': 3.8},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 3.9},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 4.0},
#    {'errNeg': -0.1,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 4.1},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.35,
#     'residual.sugar': 4.2},
#    {'errNeg': -0.3,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.15,
#     'residual.sugar': 4.3},
#    {'errNeg': 'null',
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 4.4},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 4.5},
#    {'errNeg': -0.2,
#     'errPos': 0.3,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.5,
#     'residual.sugar': 4.6},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.7,
#     'residual.sugar': 4.7},
#    {'errNeg': -0.1,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.85,
#     'residual.sugar': 4.8},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.95,
#     'residual.sugar': 4.9},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.85,
#     'residual.sugar': 5.0},
#    {'errNeg': -0.2,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 5.1},
#    {'errNeg': -0.25,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.85,
#     'residual.sugar': 5.2},
#    {'errNeg': 0.0,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.2,
#     'residual.sugar': 5.3},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 5.45},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 5.7},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.95,
#     'residual.sugar': 6.0},
#    {'errNeg': -0.05,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'residual.sugar': 6.1},
#    {'errNeg': -0.1,
#     'errPos': 0.3,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.6,
#     'residual.sugar': 6.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 6.4},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'residual.sugar': 6.5},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.9,
#     'residual.sugar': 6.75},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.6,
#     'residual.sugar': 7.5},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.4,
#     'residual.sugar': 7.6},
#    {'errNeg': 0.0,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 7.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.45,
#     'residual.sugar': 8.1},
#    {'errNeg': 0.0,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.5,
#     'residual.sugar': 8.3},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'residual.sugar': 8.5},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 9.0},
#    {'errNeg': -0.15,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.8,
#     'residual.sugar': 9.4},
#    {'errNeg': -0.15,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 10.2},
#    {'errNeg': 0.0,
#     'errPos': 0.2,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'residual.sugar': 11.1},
#    {'errNeg': -0.1,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'residual.sugar': 13.6},
#    {'errNeg': 0.0,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'residual.sugar': 22.6}],
#   'Type': 'Continuous'},
#  {'Data': [{'errNeg': -0.1,
#     'errPos': 0.1,
#     'fixed.acidity': 5.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.1},
#    {'errNeg': -0.1,
#     'errPos': 0.2,
#     'fixed.acidity': 5.3,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.2},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'fixed.acidity': 5.5,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'fixed.acidity': 5.6,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 6.0},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'fixed.acidity': 5.7,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'fixed.acidity': 5.8,
# ...
#     'volatile.acidity': 0.47},
#    {'errNeg': -0.1,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.75,
#     'volatile.acidity': 0.48},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.45,
#     'volatile.acidity': 0.49},
#    {'errNeg': 0.0,
#     'errPos': 0.05,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.5,
#     'volatile.acidity': 0.51},
#    {'errNeg': -0.2,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.45,
#     'volatile.acidity': 0.52},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'volatile.acidity': 0.54},
#    {'errNeg': -0.2,
#     'errPos': 0.15,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'volatile.acidity': 0.57},
#    {'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.0,
#     'volatile.acidity': 0.6},
#    {'errNeg': -0.5,
#     'errPos': 0.3,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.3,
#     'volatile.acidity': 0.62},
#    {'errNeg': -0.05,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.05,
#     'volatile.acidity': 0.655},
#    {'errNeg': -0.2,
#     'errPos': 0.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.8,
#     'volatile.acidity': 0.67},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 6.1,
#     'volatile.acidity': 0.76},
#    {'errNeg': 0.0,
#     'errPos': 0.1,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent',
#     'predictedYSmooth': 7.0,
#     'volatile.acidity': 1.1}],
#   'Type': 'Continuous'},
#  {'Data': [{'AlcoholContent': 'Low',
#     'errNeg': -0.1,
#     'errPos': 0.1,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA',
#     'predictedYSmooth': 5.9}],
#   'Type': 'Categorical'},
#  {'Data': [{'MSE': 0.0692,
#     'Total': 6497.0,
#     'groupByValue': 'ALL DATA',
#     'groupByVarName': 'ALL DATA'},
#    {'MSE': 0.0861,
#     'Total': 852.0,
#     'groupByValue': 'High',
#     'groupByVarName': 'AlcoholContent'},
#    {'MSE': 0.0507,
#     'Total': 2832.0,
#     'groupByValue': 'Low',
#     'groupByVarName': 'AlcoholContent'},
#    {'MSE': 0.0826,
#     'Total': 2813.0,
#     'groupByValue': 'Medium',
#     'groupByVarName': 'AlcoholContent'}],
#   'ErrType': 'MSE',
#   'Type': 'Accuracy'},
#  {'Data': [{'percentile': '0%', 'value': 3.0, 'variable': 'quality'},
#    {'percentile': '1%', 'value': 4.0, 'variable': 'quality'},
#    {'percentile': '10%', 'value': 5.0, 'variable': 'quality'},
#    {'percentile': '25%', 'value': 5.0, 'variable': 'quality'},
#    {'percentile': '50%', 'value': 6.0, 'variable': 'quality'},
#    {'percentile': '75%', 'value': 6.0, 'variable': 'quality'},
#    {'percentile': '90%', 'value': 7.0, 'variable': 'quality'},
#    {'percentile': '0%', 'value': 0.6, 'variable': 'residual.sugar'},
#    {'percentile': '1%', 'value': 0.9, 'variable': 'residual.sugar'},
#    {'percentile': '10%', 'value': 1.3, 'variable': 'residual.sugar'},
#    {'percentile': '25%', 'value': 1.8, 'variable': 'residual.sugar'},
#    {'percentile': '50%', 'value': 3.0, 'variable': 'residual.sugar'},
#    {'percentile': '75%', 'value': 8.1, 'variable': 'residual.sugar'},
#    {'percentile': '90%', 'value': 13.0, 'variable': 'residual.sugar'},
#    {'percentile': '0%', 'value': 3.8, 'variable': 'fixed.acidity'},
#    {'percentile': '1%', 'value': 5.1, 'variable': 'fixed.acidity'},
#    {'percentile': '10%', 'value': 6.0, 'variable': 'fixed.acidity'},
#    {'percentile': '25%', 'value': 6.4, 'variable': 'fixed.acidity'},
#    {'percentile': '50%', 'value': 7.0, 'variable': 'fixed.acidity'},
#    {'percentile': '75%', 'value': 7.7, 'variable': 'fixed.acidity'},
#    {'percentile': '90%', 'value': 8.8, 'variable': 'fixed.acidity'},
#    {'percentile': '0%', 'value': 1.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '1%', 'value': 4.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '10%', 'value': 9.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '25%', 'value': 17.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '50%', 'value': 29.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '75%', 'value': 41.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '90%', 'value': 54.0, 'variable': 'free.sulfur.dioxide'},
#    {'percentile': '0%', 'value': 0.22, 'variable': 'sulphates'},
#    {'percentile': '1%', 'value': 0.3, 'variable': 'sulphates'},
#    {'percentile': '10%', 'value': 0.37, 'variable': 'sulphates'},
#    {'percentile': '25%', 'value': 0.43, 'variable': 'sulphates'},
#    {'percentile': '50%', 'value': 0.51, 'variable': 'sulphates'},
#    {'percentile': '75%', 'value': 0.6, 'variable': 'sulphates'},
#    {'percentile': '90%', 'value': 0.72, 'variable': 'sulphates'},
#    {'percentile': '0%', 'value': 0.08, 'variable': 'volatile.acidity'},
#    {'percentile': '1%', 'value': 0.12, 'variable': 'volatile.acidity'},
#    {'percentile': '10%', 'value': 0.18, 'variable': 'volatile.acidity'},
#    {'percentile': '25%', 'value': 0.23, 'variable': 'volatile.acidity'},
#    {'percentile': '50%', 'value': 0.29, 'variable': 'volatile.acidity'},
#    {'percentile': '75%', 'value': 0.4, 'variable': 'volatile.acidity'},
#    {'percentile': '90%', 'value': 0.59, 'variable': 'volatile.acidity'}],
#   'Type': 'Percentile'},
#  {'Data': [{'percentileList': [{'groupByVar': 'ALL DATA',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.0},
#        {'percentiles': '1%', 'value': 4.0},
#        {'percentiles': '10%', 'value': 5.0},
#        {'percentiles': '25%', 'value': 5.0},
#        {'percentiles': '50%', 'value': 6.0},
#        {'percentiles': '75%', 'value': 6.0},
#        {'percentiles': '90%', 'value': 7.0},
#        {'percentiles': '100%', 'value': 9.0}]},
#      {'groupByVar': 'High',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.0},
#        {'percentiles': '1%', 'value': 4.0},
#        {'percentiles': '10%', 'value': 6.0},
#        {'percentiles': '25%', 'value': 6.0},
#        {'percentiles': '50%', 'value': 7.0},
#        {'percentiles': '75%', 'value': 7.0},
#        {'percentiles': '90%', 'value': 8.0},
#        {'percentiles': '100%', 'value': 9.0}]},
#      {'groupByVar': 'Low',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.0},
#        {'percentiles': '1%', 'value': 4.0},
#        {'percentiles': '10%', 'value': 5.0},
#        {'percentiles': '25%', 'value': 5.0},
#        {'percentiles': '50%', 'value': 5.0},
#        {'percentiles': '75%', 'value': 6.0},
#        {'percentiles': '90%', 'value': 6.0},
#        {'percentiles': '100%', 'value': 8.0}]},
#      {'groupByVar': 'Medium',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.0},
#        {'percentiles': '1%', 'value': 4.0},
#        {'percentiles': '10%', 'value': 5.0},
#        {'percentiles': '25%', 'value': 5.0},
#        {'percentiles': '50%', 'value': 6.0},
#        {'percentiles': '75%', 'value': 6.0},
#        {'percentiles': '90%', 'value': 7.0},
#        {'percentiles': '100%', 'value': 9.0}]}],
#     'variable': 'quality'},
#    {'percentileList': [{'groupByVar': 'ALL DATA',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.6},
#        {'percentiles': '1%', 'value': 0.9},
#        {'percentiles': '10%', 'value': 1.3},
#        {'percentiles': '25%', 'value': 1.8},
#        {'percentiles': '50%', 'value': 3.0},
#        {'percentiles': '75%', 'value': 8.1},
#        {'percentiles': '90%', 'value': 13.0},
#        {'percentiles': '100%', 'value': 65.8}]},
#      {'groupByVar': 'High',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.8},
#        {'percentiles': '1%', 'value': 0.951},
#        {'percentiles': '10%', 'value': 1.3},
#        {'percentiles': '25%', 'value': 1.8},
#        {'percentiles': '50%', 'value': 2.7},
#        {'percentiles': '75%', 'value': 4.9},
#        {'percentiles': '90%', 'value': 7.69},
#        {'percentiles': '100%', 'value': 22.6}]},
#      {'groupByVar': 'Low',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.7},
#        {'percentiles': '1%', 'value': 1.0},
#        {'percentiles': '10%', 'value': 1.5},
#        {'percentiles': '25%', 'value': 2.1},
#        {'percentiles': '50%', 'value': 6.4},
#        {'percentiles': '75%', 'value': 11.9},
#        {'percentiles': '90%', 'value': 15.0},
#        {'percentiles': '100%', 'value': 31.6}]},
#      {'groupByVar': 'Medium',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.6},
#        {'percentiles': '1%', 'value': 0.9},
#        {'percentiles': '10%', 'value': 1.2},
#        {'percentiles': '25%', 'value': 1.6},
#        {'percentiles': '50%', 'value': 2.4},
#        {'percentiles': '75%', 'value': 6.0},
#        {'percentiles': '90%', 'value': 9.65},
#        {'percentiles': '100%', 'value': 65.8}]}],
#     'variable': 'residual.sugar'},
#    {'percentileList': [{'groupByVar': 'ALL DATA',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.8},
#        {'percentiles': '1%', 'value': 5.1},
#        {'percentiles': '10%', 'value': 6.0},
#        {'percentiles': '25%', 'value': 6.4},
#        {'percentiles': '50%', 'value': 7.0},
#        {'percentiles': '75%', 'value': 7.7},
#        {'percentiles': '90%', 'value': 8.8},
#        {'percentiles': '100%', 'value': 15.9}]},
#      {'groupByVar': 'High',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.8},
#        {'percentiles': '1%', 'value': 4.7},
#        {'percentiles': '10%', 'value': 5.51},
#        {'percentiles': '25%', 'value': 6.0},
#        {'percentiles': '50%', 'value': 6.7},
#        {'percentiles': '75%', 'value': 7.2},
#        {'percentiles': '90%', 'value': 8.0},
#        {'percentiles': '100%', 'value': 15.9}]},
#      {'groupByVar': 'Low',
#       'percentileValues': [{'percentiles': '0%', 'value': 4.2},
#        {'percentiles': '1%', 'value': 5.4},
#        {'percentiles': '10%', 'value': 6.11},
#        {'percentiles': '25%', 'value': 6.5},
#        {'percentiles': '50%', 'value': 7.1},
#        {'percentiles': '75%', 'value': 7.7},
#        {'percentiles': '90%', 'value': 8.7},
#        {'percentiles': '100%', 'value': 15.0}]},
#      {'groupByVar': 'Medium',
#       'percentileValues': [{'percentiles': '0%', 'value': 4.2},
#        {'percentiles': '1%', 'value': 5.1},
#        {'percentiles': '10%', 'value': 5.9},
#        {'percentiles': '25%', 'value': 6.4},
#        {'percentiles': '50%', 'value': 7.0},
#        {'percentiles': '75%', 'value': 7.7},
#        {'percentiles': '90%', 'value': 9.0},
#        {'percentiles': '100%', 'value': 15.6}]}],
#     'variable': 'fixed.acidity'},
#    {'percentileList': [{'groupByVar': 'ALL DATA',
#       'percentileValues': [{'percentiles': '0%', 'value': 1.0},
#        {'percentiles': '1%', 'value': 4.0},
#        {'percentiles': '10%', 'value': 9.0},
#        {'percentiles': '25%', 'value': 17.0},
#        {'percentiles': '50%', 'value': 29.0},
#        {'percentiles': '75%', 'value': 41.0},
#        {'percentiles': '90%', 'value': 54.0},
#        {'percentiles': '100%', 'value': 289.0}]},
#      {'groupByVar': 'High',
#       'percentileValues': [{'percentiles': '0%', 'value': 3.0},
#        {'percentiles': '1%', 'value': 3.0},
#        {'percentiles': '10%', 'value': 10.0},
#        {'percentiles': '25%', 'value': 18.0},
#        {'percentiles': '50%', 'value': 28.0},
#        {'percentiles': '75%', 'value': 35.0},
#        {'percentiles': '90%', 'value': 43.0},
#        {'percentiles': '100%', 'value': 74.0}]},
#      {'groupByVar': 'Low',
#       'percentileValues': [{'percentiles': '0%', 'value': 1.0},
#        {'percentiles': '1%', 'value': 4.0},
#        {'percentiles': '10%', 'value': 10.0},
#        {'percentiles': '25%', 'value': 18.0},
#        {'percentiles': '50%', 'value': 33.0},
#        {'percentiles': '75%', 'value': 48.0},
#        {'percentiles': '90%', 'value': 59.0},
#        {'percentiles': '100%', 'value': 138.5}]},
#      {'groupByVar': 'Medium',
#       'percentileValues': [{'percentiles': '0%', 'value': 1.0},
#        {'percentiles': '1%', 'value': 3.0},
#        {'percentiles': '10%', 'value': 8.0},
#        {'percentiles': '25%', 'value': 15.0},
#        {'percentiles': '50%', 'value': 26.0},
#        {'percentiles': '75%', 'value': 38.0},
#        {'percentiles': '90%', 'value': 49.0},
#        {'percentiles': '100%', 'value': 289.0}]}],
#     'variable': 'free.sulfur.dioxide'},
#    {'percentileList': [{'groupByVar': 'ALL DATA',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.22},
#        {'percentiles': '1%', 'value': 0.3},
#        {'percentiles': '10%', 'value': 0.37},
#        {'percentiles': '25%', 'value': 0.43},
#        {'percentiles': '50%', 'value': 0.51},
#        {'percentiles': '75%', 'value': 0.6},
#        {'percentiles': '90%', 'value': 0.72},
#        {'percentiles': '100%', 'value': 2.0}]},
#      {'groupByVar': 'High',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.22},
#        {'percentiles': '1%', 'value': 0.27},
#        {'percentiles': '10%', 'value': 0.34},
#        {'percentiles': '25%', 'value': 0.39},
#        {'percentiles': '50%', 'value': 0.48},
#        {'percentiles': '75%', 'value': 0.6},
#        {'percentiles': '90%', 'value': 0.739},
#        {'percentiles': '100%', 'value': 1.08}]},
#      {'groupByVar': 'Low',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.28},
#        {'percentiles': '1%', 'value': 0.32},
#        {'percentiles': '10%', 'value': 0.39},
#        {'percentiles': '25%', 'value': 0.44},
#        {'percentiles': '50%', 'value': 0.5},
#        {'percentiles': '75%', 'value': 0.58},
#        {'percentiles': '90%', 'value': 0.68},
#        {'percentiles': '100%', 'value': 2.0}]},
#      {'groupByVar': 'Medium',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.25},
#        {'percentiles': '1%', 'value': 0.3},
#        {'percentiles': '10%', 'value': 0.37},
#        {'percentiles': '25%', 'value': 0.43},
#        {'percentiles': '50%', 'value': 0.52},
#        {'percentiles': '75%', 'value': 0.62},
#        {'percentiles': '90%', 'value': 0.74},
#        {'percentiles': '100%', 'value': 1.36}]}],
#     'variable': 'sulphates'},
#    {'percentileList': [{'groupByVar': 'ALL DATA',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.08},
#        {'percentiles': '1%', 'value': 0.12},
#        {'percentiles': '10%', 'value': 0.18},
#        {'percentiles': '25%', 'value': 0.23},
#        {'percentiles': '50%', 'value': 0.29},
#        {'percentiles': '75%', 'value': 0.4},
#        {'percentiles': '90%', 'value': 0.59},
#        {'percentiles': '100%', 'value': 1.58}]},
#      {'groupByVar': 'High',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.11},
#        {'percentiles': '1%', 'value': 0.15},
#        {'percentiles': '10%', 'value': 0.21},
#        {'percentiles': '25%', 'value': 0.26},
#        {'percentiles': '50%', 'value': 0.32},
#        {'percentiles': '75%', 'value': 0.395},
#        {'percentiles': '90%', 'value': 0.499},
#        {'percentiles': '100%', 'value': 1.1}]},
#      {'groupByVar': 'Low',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.085},
#        {'percentiles': '1%', 'value': 0.12},
#        {'percentiles': '10%', 'value': 0.19},
#        {'percentiles': '25%', 'value': 0.24},
#        {'percentiles': '50%', 'value': 0.3025},
#        {'percentiles': '75%', 'value': 0.44},
#        {'percentiles': '90%', 'value': 0.62},
#        {'percentiles': '100%', 'value': 1.24}]},
#      {'groupByVar': 'Medium',
#       'percentileValues': [{'percentiles': '0%', 'value': 0.08},
#        {'percentiles': '1%', 'value': 0.12},
#        {'percentiles': '10%', 'value': 0.17},
#        {'percentiles': '25%', 'value': 0.21},
#        {'percentiles': '50%', 'value': 0.27},
#        {'percentiles': '75%', 'value': 0.38},
#        {'percentiles': '90%', 'value': 0.56},
#        {'percentiles': '100%', 'value': 1.58}]}],
#     'variable': 'volatile.acidity'}],
#   'Type': 'PercentileGroup'}]

# %% [markdown]
# ### WhiteBox Sensitivity Analysis <a id=wbox_sensitivity><a>

# %%
# whitebox sensitivity behaves very similarly to WhiteBox Error

# specify your dependent variable
ydepend = 'quality'


# specify groupby variables
groupbyVars = ['Type']

# we need to create dummy variables to enhance our model further
dummydf = df.copy(deep=True)

# create dummies example using all categorical columns
dummies = pd.concat([pd.get_dummies(dummydf.loc[:, col], prefix = col) for col in dummydf.select_dtypes(include = ['category']).columns], axis = 1)
finaldf = pd.concat([dummydf.select_dtypes(include = [np.number]), dummies], axis = 1)



# create train dataset for fitting model
xtrain = finaldf.loc[:, finaldf.columns != ydepend].copy(deep = True)
# create dependent variable dataset
ytrain = finaldf.loc[:, ydepend]

# fit the model
modelobj.fit(xtrain, ytrain)

# %%
# specify featuredict as a subset of columns we want to focus on
# specify featuredict as a subset of columns we want to focus on
featuredict = {'fixed.acidity': 'FIXED ACIDITY',
               'Type': 'TYPE',
               'quality': 'SUPERQUALITY',
               'AlcoholContent': 'AC',
               'sulphates': 'SULPHATES',
              'volatile.acidity': 'VOLATILE ACIDITY',
              'residual.sugar': 'RESIDUAL SUGAR',
              'free.sulfur.dioxide': 'FREE SULFUR DIOXIDE'}

# instantiate whitebox sensitivity
WB = WhiteBoxSensitivity(modelobj = modelobj,
                   model_df = finaldf,
                   ydepend= ydepend,
                   cat_df = df,
                   groupbyvars = groupbyvars,
                   featuredict = featuredict,
                    verbose=None)
# run
WB.run()

# %%
# save the final outputs to disk
WB.save(fpath = '../output/example_winequality_sensitivity.html')
